# %% [markdown]
# <a href="https://colab.research.google.com/github/kilimo-africa/X-AE-A-12/blob/master/ML_Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.decomposition import TruncatedSVD
import pandas as pd

# %%
data = pd.read_csv('02. Xdata.csv')
#data.tail()
#data.info()

# %%
nominal = ['LOC', 'FUR', 'WATER', 'HK_SER']
ordinal = ['AMB', 'PROX_SCH', 'PROX_ROAD', 'PROX_MALL']
numerical = ['SIZE']
target = ['PRICE']

#grabbing categorical data
categorical_data = data.select_dtypes(include = ['object']).copy()
column_labels = list(categorical_data.columns)

for feature in column_labels:
  categorical_data[feature] = categorical_data[feature].astype('category')

#changing ordinal data
for feature in ordinal:
  categorical_data[feature] = categorical_data[feature].cat.codes

categorical_data.head()
# Out:
#         LOC  FUR  AMB  PROX_SCH  PROX_ROAD  PROX_MALL WATER HK_SER
# 0     karen  yes    2         0          1          1   yes    yes
# 1  madaraka  yes    1         1          1          1    no     no
# 2     karen   no    0         0          1          1   yes    yes
# 3     karen  yes    1         0          0          0   yes    yes
# 4  buruburu   no    1         0          1          1   yes    yes

# %%
#converting nominal data
data_copy = categorical_data.copy()
data_copy = pd.concat([pd.get_dummies(data_copy[nominal]), data_copy], axis=1)
data_copy.drop(nominal, axis=1, inplace=True)
# Disadvantage - dimensionality increases i.e features are increased
new_data = pd.concat([data_copy, data[numerical], data[target]], axis=1)
new_data
# Out:
#     LOC_buruburu  LOC_donholm  LOC_karen  ...  PROX_MALL       SIZE      PRICE
# 0              0            0          1  ...          1  32.502345  31.707006
# 1              0            0          0  ...          1  53.426804  68.777596
# 2              0            0          1  ...          1  61.530358  62.562382
# 3              0            0          1  ...          0  47.475640  71.546632
# 4              1            0          0  ...          1  59.813208  87.230925
# 5              0            1          0  ...          1  55.142188  78.211518
# 6              0            0          0  ...          0  52.211797  79.641973
# 7              0            0          0  ...          1  39.299567  59.171489
# 8              0            1          0  ...          0  48.105042  75.331242
# 9              0            0          1  ...          0  52.550014  71.300880
# 10             0            0          0  ...          0  45.419730  55.165677
# 11             0            0          0  ...          1  54.351635  82.478847
# 12             1            0          0  ...          0  44.164049  62.008923
# 13             0            0          1  ...          1  58.168471  75.392870
#
# [14 rows x 17 columns]

# %%
X = new_data.drop('PRICE', 1)
y = data['PRICE']

data_array = X.to_numpy()
data_array

# %%
Tsvd = TruncatedSVD(n_components=2)
data_approx = Tsvd.fit_transform(data_array)
data_approx
# Out:
# array([[32.59067248, -0.31296456],
#        [53.46778496, -0.51284032],
#        [61.5425652 ,  1.84399183],
#        [47.50479939,  0.43325415],
#        [59.84701785,  0.98922952],
#        [55.18765095, -0.66580331],
#        [52.29472771, -1.58958668],
#        [39.36187158, -1.08471401],
#        [48.13307416, -0.2865976 ],
#        [52.58778358, -1.40400383],
#        [45.44308725,  1.16566524],
#        [54.38965254,  0.58800498],
#        [44.20133601, -0.79910776],
#        [58.22132174,  0.7714815 ]])

# %%
Tsvd.singular_values_
# Out:
# array([190.59287448,   3.75044979])

# %%
#final_data = pd.concat([data_approx, data[target]], axis=1)
#final_data = pd.concat([pd.Series(data_approx.tolist()), data[target]], axis=1)

# %%
#data_approx
new_DataFrame = pd.DataFrame(data_approx,columns=['latent_1','latent_2'])
new_DataFrame
final_data = pd.concat([new_DataFrame,data[target]],axis=1)
final_data
# Out:
#      latent_1  latent_2      PRICE
# 0   32.590672 -0.312965  31.707006
# 1   53.467785 -0.512840  68.777596
# 2   61.542565  1.843992  62.562382
# 3   47.504799  0.433254  71.546632
# 4   59.847018  0.989230  87.230925
# 5   55.187651 -0.665803  78.211518
# 6   52.294728 -1.589587  79.641973
# 7   39.361872 -1.084714  59.171489
# 8   48.133074 -0.286598  75.331242
# 9   52.587784 -1.404004  71.300880
# 10  45.443087  1.165665  55.165677
# 11  54.389653  0.588005  82.478847
# 12  44.201336 -0.799108  62.008923
# 13  58.221322  0.771481  75.392870
